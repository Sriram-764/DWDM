# %% [markdown]
# <a href="https://colab.research.google.com/github/Sriram-764/DWDM/blob/main/Experiment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np

# %%
cancer = load_breast_cancer()

# %%
data = pd.DataFrame(cancer.data,columns=cancer.feature_names)

# %%
data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
data['target'] = cancer.target

# %%
data['radius_category'] = pd.cut(data['mean radius'],bins = [0,10,20,30,np.inf],labels=['0-10','10-20','20-30','>30'])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

independent = data.columns.difference(['target'])

# %%
x = data[independent].values
y = data.drop(independent, axis = 1).values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train
